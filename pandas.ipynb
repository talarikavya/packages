# %%
# !pip install pandas

# %%
import numpy as np
import pandas as pd

# %%
dataset = pd.read_csv(r"C:\Users\Talar\OneDrive\Desktop\python\student_health_data.csv")

# %% [markdown]
# # Cleaning Data Using Pandas

# %%
dataset.head()       #top of dataset
# Out:
#    Student_ID  Age Gender  Heart_Rate  Blood_Pressure_Systolic  \
# 0           1   24      M   50.663217               122.173015
# 1           2   21      F   57.926042               110.778407
# 2           3   22      M   59.294219               109.375673
# 3           4   24      M   76.826232               125.142227
# 4           5   20      M   68.342769               107.515592
#
#    Blood_Pressure_Diastolic  Stress_Level_Biosensor  Stress_Level_Self_Report  \
# 0                 84.419860                3.137350                  9.028669
# 1                 75.696145                3.699078                  5.819697
# 2                 83.803814                6.785156                  5.892360
# 3                 78.091587                6.408509                  6.884001
# 4                 80.674937                7.264719                  4.483450
#
#   Physical_Activity Sleep_Quality      Mood  Study_Hours  Project_Hours  \
# ...

# %%
dataset.head(15)
# Out:
#     Student_ID  Age Gender  Heart_Rate  Blood_Pressure_Systolic  \
# 0            1   24      M   50.663217               122.173015
# 1            2   21      F   57.926042               110.778407
# 2            3   22      M   59.294219               109.375673
# 3            4   24      M   76.826232               125.142227
# 4            5   20      M   68.342769               107.515592
# 5            6   22      M   61.744152                90.000000
# 6            7   22      F   93.097228               106.677782
# 7            8   24      F   63.361031               115.396783
# 8            9   19      F   81.671029               142.820977
# 9           10   20      M   86.211086               112.635938
# 10          11   24      F   54.300397               127.678861
# 11          12   20      M   70.739630               117.475376
# 12          13   20      F   64.824663               138.396077
# 13          14   22      F   64.010756               137.356446
# ...

# %%
dataset.tail()    #bottom dataset
# Out:
#      Student_ID  Age Gender  Heart_Rate  Blood_Pressure_Systolic  \
# 995         996   23      F   68.185217               126.031324
# 996         997   18      F   77.720216               100.627116
# 997         998   24      M   85.313237               124.362792
# 998         999   21      M   79.212477               106.370246
# 999        1000   23      F   64.576277               109.274277
#
#      Blood_Pressure_Diastolic  Stress_Level_Biosensor  \
# 995                 69.156288                8.318278
# 996                 75.569051                6.295881
# 997                 91.817614                2.896868
# 998                 77.218808                3.130484
# 999                 76.628119                6.652274
#
#      Stress_Level_Self_Report Physical_Activity Sleep_Quality      Mood  \
# 995                  6.841725          Moderate      Moderate  Stressed
# 996                  4.152130              High          Poor     Happy
# ...

# %%
dataset.tail(15)
# Out:
#      Student_ID  Age Gender  Heart_Rate  Blood_Pressure_Systolic  \
# 985         986   19      M   72.686614               125.174175
# 986         987   19      F   71.035441               123.929255
# 987         988   23      M   50.000000               101.173384
# 988         989   24      M   69.814420               114.732057
# 989         990   20      M   80.761463               160.270114
# 990         991   20      F   66.008881               101.500968
# 991         992   24      F   63.471032               129.910851
# 992         993   19      F   56.222992                90.000000
# 993         994   21      F   51.420080               132.956877
# 994         995   18      F   78.313493               106.615119
# 995         996   23      F   68.185217               126.031324
# 996         997   18      F   77.720216               100.627116
# 997         998   24      M   85.313237               124.362792
# ...

# %%
dataset.describe()   #statical describe of numeric,values..etc
# Out:
#         Student_ID        Age   Heart_Rate  Blood_Pressure_Systolic  \
# count  1000.000000  1000.0000  1000.000000              1000.000000
# mean    500.500000    20.9600    70.101863               119.835380
# std     288.819436     2.0036     9.544663                14.604307
# min       1.000000    18.0000    50.000000                90.000000
# 25%     250.750000    19.0000    63.347970               109.386868
# 50%     500.500000    21.0000    70.330916               120.051654
# 75%     750.250000    23.0000    76.425149               130.397799
# max    1000.000000    24.0000    99.650104               165.929204
#
#        Blood_Pressure_Diastolic  Stress_Level_Biosensor  \
# count               1000.000000             1000.000000
# mean                  79.854756                5.483909
# std                    9.641699                2.596108
# min                   60.000000                1.008491
# 25%                   73.115420                3.270567
# ...

# %%
dataset.info()   #missing values and data size of dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Student_ID                1000 non-null   int64
#  1   Age                       1000 non-null   int64
#  2   Gender                    1000 non-null   object
#  3   Heart_Rate                1000 non-null   float64
#  4   Blood_Pressure_Systolic   1000 non-null   float64
#  5   Blood_Pressure_Diastolic  1000 non-null   float64
#  6   Stress_Level_Biosensor    1000 non-null   float64
#  7   Stress_Level_Self_Report  1000 non-null   float64
#  8   Physical_Activity         1000 non-null   object
#  9   Sleep_Quality             1000 non-null   object
#  10  Mood                      1000 non-null   object
#  11  Study_Hours               1000 non-null   float64
#  12  Project_Hours             1000 non-null   float64
# ...

# %%
print(dataset.shape)  #get of row and coloums
# Out:
# (1000, 14)

# %%
dataset.columns     #convert list using list function
# Out:
# Index(['Student_ID', 'Age', 'Gender', 'Heart_Rate', 'Blood_Pressure_Systolic',
#        'Blood_Pressure_Diastolic', 'Stress_Level_Biosensor',
#        'Stress_Level_Self_Report', 'Physical_Activity', 'Sleep_Quality',
#        'Mood', 'Study_Hours', 'Project_Hours', 'Health_Risk_Level'],
#       dtype='object')

# %% [markdown]
# # Checking for missing values in pandas:

# %%
dataset.isnull()    #null is no value in dataset its means flase
# Out:
#      Student_ID    Age  Gender  Heart_Rate  Blood_Pressure_Systolic  \
# 0         False  False   False       False                    False
# 1         False  False   False       False                    False
# 2         False  False   False       False                    False
# 3         False  False   False       False                    False
# 4         False  False   False       False                    False
# ..          ...    ...     ...         ...                      ...
# 995       False  False   False       False                    False
# 996       False  False   False       False                    False
# 997       False  False   False       False                    False
# 998       False  False   False       False                    False
# 999       False  False   False       False                    False
#
#      Blood_Pressure_Diastolic  Stress_Level_Biosensor  \
# 0                       False                   False
# ...

# %%
dataset.isnull().any()   #contains of null value will showing of dataset
# Out:
# Student_ID                  False
# Age                         False
# Gender                      False
# Heart_Rate                  False
# Blood_Pressure_Systolic     False
# Blood_Pressure_Diastolic    False
# Stress_Level_Biosensor      False
# Stress_Level_Self_Report    False
# Physical_Activity           False
# Sleep_Quality               False
# Mood                        False
# Study_Hours                 False
# Project_Hours               False
# Health_Risk_Level           False
# dtype: bool

# %%
dataset.isnull().sum()  #finding of null values and adding values
# Out:
# Student_ID                  0
# Age                         0
# Gender                      0
# Heart_Rate                  0
# Blood_Pressure_Systolic     0
# Blood_Pressure_Diastolic    0
# Stress_Level_Biosensor      0
# Stress_Level_Self_Report    0
# Physical_Activity           0
# Sleep_Quality               0
# Mood                        0
# Study_Hours                 0
# Project_Hours               0
# Health_Risk_Level           0
# dtype: int64

# %% [markdown]
# # Slicing and extracting data in pandas

# %%
dataset['Age'].head()
# Out:
# 0    24
# 1    21
# 2    22
# 3    24
# 4    20
# Name: Age, dtype: int64

# %%
dataset[['Heart_Rate','Age']].head()
# Out:
#    Heart_Rate  Age
# 0   50.663217   24
# 1   57.926042   21
# 2   59.294219   22
# 3   76.826232   24
# 4   68.342769   20

# %%
dataset[dataset.index==4]
# Out:
#    Student_ID  Age Gender  Heart_Rate  Blood_Pressure_Systolic  \
# 4           5   20      M   68.342769               107.515592
#
#    Blood_Pressure_Diastolic  Stress_Level_Biosensor  Stress_Level_Self_Report  \
# 4                 80.674937                7.264719                   4.48345
#
#   Physical_Activity Sleep_Quality   Mood  Study_Hours  Project_Hours  \
# 4          Moderate          Poor  Happy     8.964999      15.194045
#
#   Health_Risk_Level
# 4          Moderate

# %%
dataset[dataset.index==100]
# Out:
#      Student_ID  Age Gender  Heart_Rate  Blood_Pressure_Systolic  \
# 100         101   23      F   77.321236               124.377926
#
#      Blood_Pressure_Diastolic  Stress_Level_Biosensor  \
# 100                 63.509666                 7.36551
#
#      Stress_Level_Self_Report Physical_Activity Sleep_Quality   Mood  \
# 100                  9.152645              High      Moderate  Happy
#
#      Study_Hours  Project_Hours Health_Risk_Level
# 100    26.308727      16.108854              High

# %%
dataset[dataset.index.isin(range(27))]    #in dataset are range upto student id
# Out:
#     Student_ID  Age Gender  Heart_Rate  Blood_Pressure_Systolic  \
# 0            1   24      M   50.663217               122.173015
# 1            2   21      F   57.926042               110.778407
# 2            3   22      M   59.294219               109.375673
# 3            4   24      M   76.826232               125.142227
# 4            5   20      M   68.342769               107.515592
# 5            6   22      M   61.744152                90.000000
# 6            7   22      F   93.097228               106.677782
# 7            8   24      F   63.361031               115.396783
# 8            9   19      F   81.671029               142.820977
# 9           10   20      M   86.211086               112.635938
# 10          11   24      F   54.300397               127.678861
# 11          12   20      M   70.739630               117.475376
# 12          13   20      F   64.824663               138.396077
# 13          14   22      F   64.010756               137.356446
# ...

# %%
dataset[dataset.index.isin(range(10,20))]      #in last value are n-1
# Out:
#     Student_ID  Age Gender  Heart_Rate  Blood_Pressure_Systolic  \
# 10          11   24      F   54.300397               127.678861
# 11          12   20      M   70.739630               117.475376
# 12          13   20      F   64.824663               138.396077
# 13          14   22      F   64.010756               137.356446
# 14          15   21      F   75.553768               137.642627
# 15          16   20      M   63.771295                93.990247
# 16          17   23      F   65.040310               123.100861
# 17          18   22      F   68.318851               131.384079
# 18          19   19      M   66.266007               125.723078
# 19          20   21      F   58.264298               129.548945
#
#     Blood_Pressure_Diastolic  Stress_Level_Biosensor  \
# 10                 81.161731                2.621428
# 11                 71.551015                1.988768
# 12                 84.015606                8.953156
# ...

# %% [markdown]
# # Using of .loc[] And .iloc[] of fetch rows

# %%
dataset.loc[10]
# Out:
# Student_ID                          11
# Age                                 24
# Gender                               F
# Heart_Rate                   54.300397
# Blood_Pressure_Systolic     127.678861
# Blood_Pressure_Diastolic     81.161731
# Stress_Level_Biosensor        2.621428
# Stress_Level_Self_Report      8.990359
# Physical_Activity                 High
# Sleep_Quality                 Moderate
# Mood                             Happy
# Study_Hours                  24.772251
# Project_Hours                21.214005
# Health_Risk_Level             Moderate
# Name: 10, dtype: object

# %%
dataset.loc[100]
# Out:
# Student_ID                         101
# Age                                 23
# Gender                               F
# Heart_Rate                   77.321236
# Blood_Pressure_Systolic     124.377926
# Blood_Pressure_Diastolic     63.509666
# Stress_Level_Biosensor         7.36551
# Stress_Level_Self_Report      9.152645
# Physical_Activity                 High
# Sleep_Quality                 Moderate
# Mood                             Happy
# Study_Hours                  26.308727
# Project_Hours                16.108854
# Health_Risk_Level                 High
# Name: 100, dtype: object

# %%
dataset.iloc[20]
# Out:
# Student_ID                          21
# Age                                 23
# Gender                               M
# Heart_Rate                   77.959065
# Blood_Pressure_Systolic     120.875265
# Blood_Pressure_Diastolic     82.961848
# Stress_Level_Biosensor        3.167234
# Stress_Level_Self_Report      4.973806
# Physical_Activity                  Low
# Sleep_Quality                 Moderate
# Mood                           Neutral
# Study_Hours                  19.840403
# Project_Hours                22.547245
# Health_Risk_Level                  Low
# Name: 20, dtype: object

# %%
dataset.iloc[100]
# Out:
# Student_ID                         101
# Age                                 23
# Gender                               F
# Heart_Rate                   77.321236
# Blood_Pressure_Systolic     124.377926
# Blood_Pressure_Diastolic     63.509666
# Stress_Level_Biosensor         7.36551
# Stress_Level_Self_Report      9.152645
# Physical_Activity                 High
# Sleep_Quality                 Moderate
# Mood                             Happy
# Study_Hours                  26.308727
# Project_Hours                16.108854
# Health_Risk_Level                 High
# Name: 100, dtype: object

# %%
dataset.iloc[5:20]
# Out:
#     Student_ID  Age Gender  Heart_Rate  Blood_Pressure_Systolic  \
# 5            6   22      M   61.744152                90.000000
# 6            7   22      F   93.097228               106.677782
# 7            8   24      F   63.361031               115.396783
# 8            9   19      F   81.671029               142.820977
# 9           10   20      M   86.211086               112.635938
# 10          11   24      F   54.300397               127.678861
# 11          12   20      M   70.739630               117.475376
# 12          13   20      F   64.824663               138.396077
# 13          14   22      F   64.010756               137.356446
# 14          15   21      F   75.553768               137.642627
# 15          16   20      M   63.771295                93.990247
# 16          17   23      F   65.040310               123.100861
# 17          18   22      F   68.318851               131.384079
# 18          19   19      M   66.266007               125.723078
# ...

# %%
dataset.to_numpy() #simple convert of pandas into numpy
# Out:
# array([[1, 24, 'M', ..., 34.520972884506875, 16.80095639050803,
#         'Moderate'],
#        [2, 21, 'F', ..., 16.763846015109607, 15.79115434826643,
#         'Moderate'],
#        [3, 22, 'M', ..., 44.2037984802835, 25.67843704706686, 'Moderate'],
#        ...,
#        [998, 24, 'M', ..., 15.330940546480807, 19.010783955814063,
#         'Moderate'],
#        [999, 21, 'M', ..., 31.921142670786686, 9.159565239460758, 'Low'],
#        [1000, 23, 'F', ..., 30.944069534041603, 20.068335429334187,
#         'Moderate']], dtype=object)

# %% [markdown]
# # Missing Values of Dealing in pandas

# %% [markdown]
# 1.Dropping Missing Values:-

# %%
data = dataset.dropna()

# %%
data.isnull().sum()  #is no values in dataset
# Out:
# Student_ID                  0
# Age                         0
# Gender                      0
# Heart_Rate                  0
# Blood_Pressure_Systolic     0
# Blood_Pressure_Diastolic    0
# Stress_Level_Biosensor      0
# Stress_Level_Self_Report    0
# Physical_Activity           0
# Sleep_Quality               0
# Mood                        0
# Study_Hours                 0
# Project_Hours               0
# Health_Risk_Level           0
# dtype: int64

# %%
data.shape
# Out:
# (1000, 14)

# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\Talar\OneDrive\Desktop\python\student_health_data.csv")

# %%
data.head()
# Out:
#    Student_ID  Age Gender  Heart_Rate  Blood_Pressure_Systolic  \
# 0           1   24      M   50.663217               122.173015
# 1           2   21      F   57.926042               110.778407
# 2           3   22      M   59.294219               109.375673
# 3           4   24      M   76.826232               125.142227
# 4           5   20      M   68.342769               107.515592
#
#    Blood_Pressure_Diastolic  Stress_Level_Biosensor  Stress_Level_Self_Report  \
# 0                 84.419860                3.137350                  9.028669
# 1                 75.696145                3.699078                  5.819697
# 2                 83.803814                6.785156                  5.892360
# 3                 78.091587                6.408509                  6.884001
# 4                 80.674937                7.264719                  4.483450
#
#   Physical_Activity Sleep_Quality      Mood  Study_Hours  Project_Hours  \
# ...

# %%
data.isnull().sum()
# Out:
# Student_ID                  0
# Age                         0
# Gender                      0
# Heart_Rate                  0
# Blood_Pressure_Systolic     0
# Blood_Pressure_Diastolic    0
# Stress_Level_Biosensor      0
# Stress_Level_Self_Report    0
# Physical_Activity           0
# Sleep_Quality               0
# Mood                        0
# Study_Hours                 0
# Project_Hours               0
# Health_Risk_Level           0
# dtype: int64

# %%
data.shape
# Out:
# (1000, 14)

# %%
print(data.isnull().sum())
# Out:
# Student_ID                  0
# Age                         0
# Gender                      0
# Heart_Rate                  0
# Blood_Pressure_Systolic     0
# Blood_Pressure_Diastolic    0
# Stress_Level_Biosensor      0
# Stress_Level_Self_Report    0
# Physical_Activity           0
# Sleep_Quality               0
# Mood                        0
# Study_Hours                 0
# Project_Hours               0
# Health_Risk_Level           0
# dtype: int64

# %%
data.dropna
# Out:
# <bound method DataFrame.dropna of      Student_ID  Age Gender  Heart_Rate  Blood_Pressure_Systolic  \
# 0             1   24      M   50.663217               122.173015
# 1             2   21      F   57.926042               110.778407
# 2             3   22      M   59.294219               109.375673
# 3             4   24      M   76.826232               125.142227
# 4             5   20      M   68.342769               107.515592
# ..          ...  ...    ...         ...                      ...
# 995         996   23      F   68.185217               126.031324
# 996         997   18      F   77.720216               100.627116
# 997         998   24      M   85.313237               124.362792
# 998         999   21      M   79.212477               106.370246
# 999        1000   23      F   64.576277               109.274277
#
#      Blood_Pressure_Diastolic  Stress_Level_Biosensor  \
# 0                   84.419860                3.137350
# ...

# %% [markdown]
# 2.Replacing of values:

# %%
data1 = pd.read_csv(r"C:\Users\Talar\OneDrive\Desktop\python\student_health_data.csv",usecols=['Age','Gender','Heart_Rate'])

# %%
data1.head()
# Out:
#    Age Gender  Heart_Rate
# 0   24      M   50.663217
# 1   21      F   57.926042
# 2   22      M   59.294219
# 3   24      M   76.826232
# 4   20      M   68.342769

# %%
mean_value = data1['Age']

# %%
print(mean_value)
# Out:
# 0      24
# 1      21
# 2      22
# 3      24
# 4      20
#        ..
# 995    23
# 996    18
# 997    24
# 998    21
# 999    23
# Name: Age, Length: 1000, dtype: int64

# %%
data0 = data.fillna(mean_value)

# %%
data.head(10)
# Out:
#    Student_ID  Age Gender  Heart_Rate  Blood_Pressure_Systolic  \
# 0           1   24      M   50.663217               122.173015
# 1           2   21      F   57.926042               110.778407
# 2           3   22      M   59.294219               109.375673
# 3           4   24      M   76.826232               125.142227
# 4           5   20      M   68.342769               107.515592
# 5           6   22      M   61.744152                90.000000
# 6           7   22      F   93.097228               106.677782
# 7           8   24      F   63.361031               115.396783
# 8           9   19      F   81.671029               142.820977
# 9          10   20      M   86.211086               112.635938
#
#    Blood_Pressure_Diastolic  Stress_Level_Biosensor  Stress_Level_Self_Report  \
# 0                 84.419860                3.137350                  9.028669
# 1                 75.696145                3.699078                  5.819697
# ...

# %%
data2 = data.fillna('median')

# %%
median_value = data1['Age']

# %%
print(median_value)
# Out:
# 0      24
# 1      21
# 2      22
# 3      24
# 4      20
#        ..
# 995    23
# 996    18
# 997    24
# 998    21
# 999    23
# Name: Age, Length: 1000, dtype: int64

# %% [markdown]
# 3.Duplicate Date :-

# %%
data3 = pd.read_csv(r"C:\Users\Talar\OneDrive\Desktop\python\student_health_data.csv",usecols=['Age','Gender','Heart_Rate'])

# %%
data.head(5)
# Out:
#    Student_ID  Age Gender  Heart_Rate  Blood_Pressure_Systolic  \
# 0           1   24      M   50.663217               122.173015
# 1           2   21      F   57.926042               110.778407
# 2           3   22      M   59.294219               109.375673
# 3           4   24      M   76.826232               125.142227
# 4           5   20      M   68.342769               107.515592
#
#    Blood_Pressure_Diastolic  Stress_Level_Biosensor  Stress_Level_Self_Report  \
# 0                 84.419860                3.137350                  9.028669
# 1                 75.696145                3.699078                  5.819697
# 2                 83.803814                6.785156                  5.892360
# 3                 78.091587                6.408509                  6.884001
# 4                 80.674937                7.264719                  4.483450
#
#   Physical_Activity Sleep_Quality      Mood  Study_Hours  Project_Hours  \
# ...

# %%
data.shape
# Out:
# (1000, 14)

# %%
data = data3.drop_duplicates

# %%
data3.shape
# Out:
# (1000, 3)

# %% [markdown]
# Renaming colunmss

# %%
data1 = pd.read_csv(r"C:\Users\Talar\OneDrive\Desktop\python\student_health_data.csv",usecols=['Age','Gender','Heart_Rate'])

# %%
data1.rename(columns={'Age':'New_Age'},inplace = True)

# %%
data1.head()
# Out:
#    New_Age Gender  Heart_Rate
# 0       24      M   50.663217
# 1       21      F   57.926042
# 2       22      M   59.294219
# 3       24      M   76.826232
# 4       20      M   68.342769

# %%
#mean 

import pandas as pd
s = pd.Series([39,38,85,73,26,84,62,38])
s.mean()
# Out:
# 55.625

# %%
df = pd.DataFrame({'a': [1, 2], 'b': [2, 3]}, index=['tiger', 'zebra'])
df.mean()      #With a DataFrame
# Out:
# a    1.5
# b    2.5
# dtype: float64

# %%
df = pd.DataFrame({'a': [1, 2], 'b': ['T', 'Z']},index=['tiger', 'zebra']) 
df.mean(numeric_only=True)               # numeric_only should be set to True to avoid getting an error
# Out:
# a    1.5
# dtype: float64

# %%
#median

s = pd.Series([39,38,85,73,26,84,62,38])
s.median()
# Out:
# 50.5

# %%
df = pd.DataFrame({'a': [1, 2], 'b': ['T', 'Z']},index=['tiger', 'zebra'])
df.median(numeric_only=True)
# Out:
# a    1.5
# dtype: float64

# %%
#mode 
s = pd.Series([39,38,85,73,26,84,62,38])
s.mode()
# Out:
# 0    38
# dtype: int64
